# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f_m= 3.0
n_points = np.linspace(0,1,2000)
c_t = np.cos(2*np.pi*f_m*n_points)

# %%
n_points
# Out:
# array([0.00000000e+00, 5.00250125e-04, 1.00050025e-03, ...,
#        9.98999500e-01, 9.99499750e-01, 1.00000000e+00], shape=(2000,))

# %%
plt.plot(n_points,c_t)
plt.show()

# %%
sampling_rates = [30, 8, 5]
samples = np.arange(0,100,1/30)

# %%
samples
# Out:
# array([0.00000000e+00, 3.33333333e-02, 6.66666667e-02, ...,
#        9.99000000e+01, 9.99333333e+01, 9.99666667e+01], shape=(3000,))
